# %% [markdown]
# <a href="https://colab.research.google.com/github/tsarkar77/Senior-travel/blob/main/Expensetracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Expenses =[]

while True:

 print("1. View Expenses")
 print("2. Add Expense")
 print("3. Delete Expense")
 print("4. Show Total Spending")
 print("5. Exit")

 choice = int(input("Enter your choice: "))

 if choice == 1:
  print(Expenses)

 elif choice == 2:
    name=input("Enter your expense name: ")
    amount=int(input("Enter your expense amount:"))
    expense = {"name":name,"amount":amount}
    Expenses.append(expense)
    print("Expense added successfully")
    total_spent = sum(expense["amount"] for expense in Expenses)
    print(total_spent)

 elif choice == 3:
    delete=input("Enter the expense to delete: ")
    for expense in Expenses:
     if expense["name"] == delete:
        Expenses.remove(expense)
        print("Expense deleted successfully")
     else :
      print("Expense not found")

 elif choice == 4:
   print(total_spent)

 elif choice == 5:
    break

 else:
    print("Invalid choice")
# Out:
# 1. View Expenses
# 2. Add Expense
# 3. Delete Expense
# 4. Show Total Spending
# 5. Exit
# Enter your choice: 2
# Enter your expense name: e
# Enter your expense amount:520
# Expense added successfully
# 520
# 1. View Expenses
# 2. Add Expense
# 3. Delete Expense
# 4. Show Total Spending
# 5. Exit
# Enter your choice: 3
# Enter the expense to delete: e
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21666/252048883.py in <cell line: 0>()
#      27     for expense in Expenses:
#      28      if expense["name"] == delete:
# ---> 29        Expenses.remove(delete)
#      30      else :
#      31       print("Expense not found")
#
# ValueError: list.remove(x): x not in list
