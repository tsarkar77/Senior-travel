# %% [markdown]
# <a href="https://colab.research.google.com/github/tsarkar77/Senior-travel/blob/main/Rockpaperscissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
options=["rock","paper","scissors"]


def rockpaperscissors():

 pc_choice= random.choice(options)
 my_choice= input("Choose either rock/paper/scissors:")
 if my_choice=="rock" and pc_choice=="rock":
  print("Pc chose",pc_choice,"so no points for you.")
 elif my_choice=="rock" and pc_choice=="paper":
  print("Pc chose",pc_choice,"so no points for you.")
 elif my_choice=="rock" and pc_choice=="scissors":
  print("Pc chose",pc_choice,"you win 1 point.")
 elif my_choice=="paper" and pc_choice=="rock":
  print("Pc chose",pc_choice,"you win 1 point")
 elif my_choice=="paper" and pc_choice=="paper":
  print("Pc chose",pc_choice,"so no points for you.")
 elif my_choice=="paper" and pc_choice=="scissors":
  print("Pc chose",pc_choice,"so no points for you.")
 elif my_choice=="scissors" and pc_choice=="rock":
  print("Pc chose",pc_choice,"so no points for you.")
 elif my_choice=="scissors" and pc_choice=="paper":
  print("Pc chose",pc_choice,"you win 1 point!")
 elif my_choice=="scissors" and pc_choice=="scissors":
  print("Pc chose",pc_choice,"so no points for you.")

 Playagain=(input("Play again?:"))
 if Playagain=="yes":
  rockpaperscissors()
 elif Playagain=="no":
    print("game over")


rockpaperscissors()
# Out:
# Choose either rock/paper/scissors:scissors
# Pc chose scissors so no points for you.
# Play again?:yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_936/2208894785.py in <cell line: 0>()
#      33
#      34
# ---> 35 rockpaperscissors()
#      36
#
# /tmp/ipykernel_936/2208894785.py in rockpaperscissors()
#      28  Playagain=(input("Play again?:"))
#      29  if Playagain=="yes":
# ---> 30   rockpaperscissors()
#      31  elif Playagain=="no":
#      32     print("game over")
#
# /tmp/ipykernel_936/2208894785.py in rockpaperscissors()
#       6
#       7  pc_choice= random.choice(options)
# ----> 8  my_choice= input("Choose either rock/paper/scissors:")
#       9  if my_choice=="rock" and pc_choice=="rock":
#      10   print("Pc chose",pc_choice,"so no points for you.")
#
# ...
