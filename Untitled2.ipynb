# %%
# !pip install transformers langchain langchain-community duckduckgo-search torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 104.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
def add(a,b):
  return a+b
def subs(a,b):
  return a-b
def mult(a,b):
  return a*b
def div(a,b):
  return a/b
  if b==0: return "cannot divide"

def calc():
  print ("select operation")
  print ("1. add")
  print ("2. subtract")
  print ("3. multiply")
  print ("4. divide")

  choice = input("Choose operation: 1/2/3/4")
  num1= float(input("First number is:"))
  num2= float(input("Second number is:"))


  if choice=='1':
   print (add(num1,num2))

  elif choice=='2':
   print (subs(num1,num2))

  elif choice=='3':
   print (mult(num1,num2))

  elif choice=='4':
   print (div(num1,num2))

  else:
   print ("Invaid input")

calc()
# Out:
# select operation
# 1. add
# 2. subtract
# 3. multiply
# 4. divide
# Choose operation: 1/2/3/42
# First number is:60
# Second number is:90
# -30.0
